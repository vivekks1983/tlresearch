# %%
from pandas.io.json import json_normalize
from pymongo import MongoClient
import numpy as np
import matplotlib.pyplot as plt
import datetime
from matplotlib.gridspec import GridSpec

import pandas as pd
print()
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for FOI'+'\x1b[0m')
print()
print()
a = "       FOI Data"
print(a)


client = MongoClient()
db = client.test
collection = db['HMODataFOI']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)

client = MongoClient()
db = client.test
collection = db['HMODataFOI']
cursor = list(collection.find({}, {'_id': False}))
df1 =  pd.DataFrame(list(cursor))
df=df1[['Licensed','Unlicensed2016','Unlicensed2015']].astype(float)
ind = np.arange(26)
width = 0.35
ax = df.plot(kind='bar', title ="HMO Data for FOI",figsize=(20,10),legend=True, fontsize=15)
ax.set_xlabel("Council",fontsize=12)
ax.set_xticklabels(df1['Council'])
ax.set_xticks(ind + width/2)
ax.set_ylabel("Licensed/Unlicensed Houses",fontsize=12)
plt.show()
# Out:
#                                   HMO Data for FOI
#
#
#        FOI Data
