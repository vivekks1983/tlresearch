# %%
from IPython.display import Image
Image(filename='/home/ubuntu/project/Notebooks/TriLogo5.png')

# %%
from pandas.io.json import json_normalize
from pymongo import MongoClient
import numpy as np
import matplotlib.pyplot as plt
import datetime
from matplotlib.gridspec import GridSpec
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))
print('\x1b[1;31m'+'                                  HMO Data for Barnet'+'\x1b[0m')
print()
print()
a = "       Barnet Floor Chart                                  Barnet Tenants Charts"
print(a)

client = MongoClient()
db = client.test
collection = db['HmoListBarnet']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)
threerooms=0
fourroom=0
sixroom=0
fiveroom=0
lessthenfive=0
fiveTenants=0
sixTenants=0
seventenents=0
eighttenents=0
ninetenents=0
greatertheneight=0

for index, row in result.iterrows():
    if int(row['PermittedNumberofOccupants']) < 5:
        lessthenfive=lessthenfive+1
    if int(row['PermittedNumberofOccupants']) == 5:
        fiveTenants=fiveTenants+1
    elif int(row['PermittedNumberofOccupants']) == 6:
        sixTenants=sixTenants+1
    elif int(row['PermittedNumberofOccupants']) == 7:
        seventenents=seventenents+1
    elif int(row['PermittedNumberofOccupants']) == 8:
        eighttenents=eighttenents+1
    elif int(row['PermittedNumberofOccupants']) > 8:
        greatertheneight=greatertheneight+1


the_grid = GridSpec(1, 2)

for index, row in result.iterrows():
    if int(row['Rooms']) == 3:
        threerooms=threerooms+1
    elif int(row['Rooms']) == 4:
        fourroom=fourroom+1
    elif int(row['Rooms']) == 5:
        fiveroom=fiveroom+1
    elif int(row['Rooms']) == 6:
        sixroom=sixroom+1

        
labels =  '3 Floors', '5 Floors', '4 Floors', '6 Floors' 
sizes = [threerooms, fiveroom,fourroom, sixroom]
explode = (0, 0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')


labels1 =  'Less then 5 Tenants', '5 Tenants', '6 Tenants', '7 Tenants', '8 Tenants' ,  'More then 8 Tenants'
sizes1 = [lessthenfive,fiveTenants, sixTenants, seventenents,eighttenents,greatertheneight]
explode1 = (0, 0.1, 0, 0, 0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.subplot(the_grid[0, 0], aspect=1)
plt.subplots_adjust(left=1, bottom=1, right=3, top=2, wspace=2, hspace=2)


plt.pie(sizes, explode=explode,
                                    labels=labels, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)

plt.subplot(the_grid[0, 1], aspect=1)

plt.pie(sizes1, explode=explode1,
                                    labels=labels1, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)



plt.show()
# Out:
#                                   HMO Data for Barnet
#
#
#        Barnet Floor Chart                                  Barnet Tenants Charts

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/project/Notebooks/Barnet.png')

# %%
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for Camden'+'\x1b[0m')
print()
print()
a = "       Camden Floor Chart                                  Camden Tenants Charts"
print(a)

client = MongoClient()
db = client.test
collection = db['HmoListCamden']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)
threerooms=0
fourroom=0
sixroom=0
fiveroom=0
lessthenfive=0
sixTenants=0
seventenents=0
eighttenents=0
ninetenents=0
greaterthennine=0

for index, row in result.iterrows():
    if int(row['MaximumNumberOfPersons']) == 1:
        lessthenfive=lessthenfive+1
    if int(row['MaximumNumberOfPersons']) == 2:
        sixTenants=sixTenants+1
    elif int(row['MaximumNumberOfPersons']) == 3:
        seventenents=seventenents+1
    elif int(row['MaximumNumberOfPersons']) == 4:
        eighttenents=eighttenents+1
    elif int(row['MaximumNumberOfPersons']) == 5:
        ninetenents=ninetenents+1
    elif int(row['MaximumNumberOfPersons']) > 5:
        greaterthennine=greaterthennine+1

for index, row in result.iterrows():
    if int(row['StoreysOfHMO']) == 3:
        threerooms=threerooms+1
    elif int(row['StoreysOfHMO']) == 4:
        fourroom=fourroom+1
    elif int(row['StoreysOfHMO']) == 5:
        fiveroom=fiveroom+1
    elif int(row['StoreysOfHMO']) == 6:
        sixroom=sixroom+1

the_grid = GridSpec(1, 2)
        
labels =  '3 Floors', '5 Floors', '4 Floors', '6 Floors' 
sizes = [threerooms, fiveroom,fourroom, sixroom]
explode = (0, 0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

labels1 =  '3 Tenants', '4 Tenants', '2 Tenants', '5 Tenants', '1 Tenants' ,  '>5 Tenants'
sizes1 = [ seventenents, eighttenents,sixTenants,ninetenents,lessthenfive,greaterthennine]
explode1 = (0, 0.1, 0, 0, 0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')


plt.subplot(the_grid[0, 0], aspect=1)
plt.subplots_adjust(left=1, bottom=1, right=3, top=2, wspace=2, hspace=2)


plt.pie(sizes, explode=explode,
                                    labels=labels, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)

plt.subplot(the_grid[0, 1], aspect=1)

plt.pie(sizes1, explode=explode1,
                                    labels=labels1, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)



plt.show()
# Out:
#                                   HMO Data for Camden
#
#
#        Camden Floor Chart                                  Camden Tenants Charts

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/project/Notebooks/Camden.png')

# %%
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for Chalsea'+'\x1b[0m')
print()
print()
a = "       Chelsea Floor Chart                                  Chalsea Tenants Charts"
print(a)


client = MongoClient()
db = client.test
collection = db['HmoListChelsea']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)
threerooms=0
fourroom=0
sixroom=0
fiveroom=0
lessthen10=0
between10and20=0
between20and30=0
between30and40=0
greaterthen40=0

for index, row in result.iterrows():
#    print(row)
    if int(row['NumberOfOccupants']) <= 10:
        lessthen10=lessthen10+1
    if int(row['NumberOfOccupants']) > 10 and int(row['NumberOfOccupants']) <= 20:
        between10and20=between10and20+1
    elif int(row['NumberOfOccupants']) > 20 and int(row['NumberOfOccupants']) <= 30:
        between20and30=between20and30+1
    elif int(row['NumberOfOccupants']) > 30 and int(row['NumberOfOccupants']) <= 40:
        between30and40=between30and40+1
    elif int(row['NumberOfOccupants']) > 40:
        greaterthen40=greaterthen40+1


for index, row in result.iterrows():
    if int(row['NoofBasement']) == 3:
        threerooms=threerooms+1
    elif int(row['NoofBasement']) == 4:
        fourroom=fourroom+1
    elif int(row['NoofBasement']) == 5:
        fiveroom=fiveroom+1
    elif int(row['NoofBasement']) == 6:
        sixroom=sixroom+1

labels =  '3 Floors', '5 Floors', '4 Floors', '6 Floors' 
sizes = [threerooms, fiveroom,fourroom, sixroom]
explode = (0, 0, 0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

labels1 =  'Less then 5 Tenants', '5 Tenants', '6 Tenants', '7 Tenants', '8 Tenants' 
sizes1 = [lessthen10,between10and20, between20and30, between30and40,greaterthen40]
explode1 = (0, 0.1, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')


plt.subplot(the_grid[0, 0], aspect=1)
plt.subplots_adjust(left=1, bottom=1, right=3, top=2, wspace=2, hspace=2)


plt.pie(sizes, explode=explode,
                                    labels=labels, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)

plt.subplot(the_grid[0, 1], aspect=1)

plt.pie(sizes1, explode=explode1,
                                    labels=labels1, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)



plt.show()
# Out:
#                                   HMO Data for Chalsea
#
#
#        Chelsea Floor Chart                                  Chalsea Tenants Charts

# %%
from IPython.display import Image;
Image(filename='/home/ubuntu/project/Notebooks/Chalsea.png')

# %%
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for Hammersmith'+'\x1b[0m')
print()
print()
a = "       Hammersmith Floor Chart                         Hammersmith Tenants Charts"
print(a)

client = MongoClient()
db = client.test
collection = db['HmoListHammersmith']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)
threerooms=0
fourroom=0
sixroom=0
fiveroom=0
lessthenfive=0
sixTenants=0
seventenents=0
eighttenents=0
ninetenents=0
greaterthennine=0

for index, row in result.iterrows():
    if int(row['Permittednoofpersons']) <= 5:
        lessthenfive=lessthenfive+1
    if int(row['Permittednoofpersons']) == 6:
        sixTenants=sixTenants+1
    elif int(row['Permittednoofpersons']) == 7:
        seventenents=seventenents+1
    elif int(row['Permittednoofpersons']) == 8:
        eighttenents=eighttenents+1
    elif int(row['Permittednoofpersons']) == 9:
        ninetenents=ninetenents+1
    elif int(row['Permittednoofpersons']) > 9:
        greaterthennine=greaterthennine+1

        
for index, row in result.iterrows():
    if int(row['Nooffloors']) == 3:
        threerooms=threerooms+1
    elif int(row['Nooffloors']) == 4:
        fourroom=fourroom+1
    elif int(row['Nooffloors']) == 5:
        fiveroom=fiveroom+1
    elif int(row['Nooffloors']) == 6:
        sixroom=sixroom+1

labels =  '3 Floors', '5 Floors', '4 Floors', '6 Floors' 
sizes = [threerooms, fiveroom,fourroom, sixroom]
explode = (0, 0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

labels1 =  'Less then 5 Tenants', '5 Tenants', '6 Tenants', '7 Tenants', '8 Tenants' ,  '9 Tenants'
sizes1 = [lessthenfive,sixTenants, seventenents, eighttenents,ninetenents,greaterthennine]
explode1 = (0, 0.1, 0, 0, 0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')


plt.subplot(the_grid[0, 0], aspect=1)
plt.subplots_adjust(left=1, bottom=1, right=3, top=2, wspace=2, hspace=2)


plt.pie(sizes, explode=explode,
                                    labels=labels, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)

plt.subplot(the_grid[0, 1], aspect=1)

plt.pie(sizes1, explode=explode1,
                                    labels=labels1, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)



plt.show()
# Out:
#                                   HMO Data for Hammersmith
#
#
#        Hammersmith Floor Chart                         Hammersmith Tenants Charts

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/project/Notebooks/Hammersmith.png')

# %%
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for Hillington'+'\x1b[0m')
print()
print()
a = "       Hillington Floor Chart                         Hillington Tenants Charts"
print(a)

client = MongoClient()
db = client.test
collection = db['HmoListHillingdon']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)
lessthen2room=0
morethe3room=0
tworoom=0
threeroom=0
lessthenfive=0
fiveTenants=0
sixtenants=0
seventenents=0
greaterthenseven=0

for index, row in result.iterrows():
    if int(row['Tenants']) < 5:
        lessthenfive=lessthenfive+1
    if int(row['Tenants']) == 5:
        fiveTenants=fiveTenants+1
    elif int(row['Tenants']) == 6:
        sixtenants=sixtenants+1
    elif int(row['Tenants']) == 7:
        seventenents=seventenents+1
    elif int(row['Tenants']) > 7:
        greaterthenseven=greaterthenseven+1


for index, row in result.iterrows():
    if int(row['Floors']) == 2:
        tworoom=tworoom+1
    elif int(row['Floors']) == 3:
        threeroom=threeroom+1
    elif int(row['Floors']) < 2:
        lessthen2room=lessthen2room+1
    elif int(row['Floors']) > 3:
        morethe3room=morethe3room+1

labels =  '2 Floors', '<2 Floors', '3 Floors', '>3 Floors' 
sizes = [tworoom,lessthen2room, threeroom, morethe3room]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

labels1 =  'Less then 5 Tenants', '5 Tenants', '6 Tenants', '7 Tenants', '8 Tenants' 
sizes1 = [lessthenfive,fiveTenants, sixtenants, seventenents,greaterthenseven]
explode1 = (0, 0.1, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')


plt.subplot(the_grid[0, 0], aspect=1)
plt.subplots_adjust(left=1, bottom=1, right=3, top=2, wspace=2, hspace=2)


plt.pie(sizes, explode=explode,
                                    labels=labels, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)

plt.subplot(the_grid[0, 1], aspect=1)

plt.pie(sizes1, explode=explode1,
                                    labels=labels1, autopct='%1.1f%%',
                                    shadow=True, radius=2.0)



plt.show()
# Out:
#                                   HMO Data for Hillington
#
#
#        Hillington Floor Chart                         Hillington Tenants Charts

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/project/Notebooks/Hillington.png')

# %%
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for Havering'+'\x1b[0m')
print()
print()
a = "       Havering Tenants Charts"
print(a)

client = MongoClient()
db = client.test
collection = db['HmoListHavering']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)
lessthenfive=0
fiveTenants=0
sixTenants=0
seventenents=0
eighttenents=0
ninetenents=0
greatertheneight=0

for index, row in result.iterrows():
    if int(row['MaxNoofoccupants']) == 5:
        fiveTenants=fiveTenants+1
    elif int(row['MaxNoofoccupants']) == 6:
        sixTenants=sixTenants+1
    elif int(row['MaxNoofoccupants']) == 7:
        seventenents=seventenents+1
    elif int(row['MaxNoofoccupants']) == 8:
        eighttenents=eighttenents+1
    elif int(row['MaxNoofoccupants']) > 8:
        greatertheneight=greatertheneight+1

labels = '5 Tenants', '6 Tenants', '7 Tenants', '8 Tenants' ,  'More then 8 Tenants'
sizes = [fiveTenants, sixTenants, seventenents,eighttenents,greatertheneight]
explode = (0.1, 0, 0, 0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')


plt.subplot(the_grid[0, 0], aspect=1)
plt.subplots_adjust(left=1, bottom=1, right=3, top=2, wspace=2, hspace=2)


plt.pie(sizes, explode=explode,
                                    labels=labels, autopct='%1.1f%%',
                                    shadow=True, radius=1.4)

plt.show()
# Out:
#                                   HMO Data for Havering
#
#
#        Havering Tenants Charts

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/project/Notebooks/Havering.png')

# %%
import pandas as pd
print()
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for FOI 2015'+'\x1b[0m')
print()
print()
a = "       FOI Data"
print(a)


client = MongoClient()
db = client.test
collection = db['HMODataFOI']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)

client = MongoClient()
db = client.test
collection = db['HMODataFOI']
cursor = list(collection.find({}, {'_id': False}))
df1 =  pd.DataFrame(list(cursor))
df=df1[['Licensed','Unlicensed2015']].astype(float)
ind = np.arange(26)
width = 0.35
ax = df.plot(kind='bar', title ="HMO Data for FOI 2015",figsize=(20,10),legend=True, fontsize=15)
ax.set_xlabel("Council",fontsize=12)
ax.set_xticklabels(df1['Council'])
ax.set_xticks(ind + width/2)
ax.set_ylabel("Licensed/Unlicensed Houses",fontsize=12)
plt.show()
# Out:
#                                   HMO Data for FOI 2015
#
#
#        FOI Data

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/project/Notebooks/LUN2015.png')

# %%
import pandas as pd
print()
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for FOI 2016'+'\x1b[0m')
print()
print()
a = "       FOI Data"
print(a)


client = MongoClient()
db = client.test
collection = db['HMODataFOI']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)

client = MongoClient()
db = client.test
collection = db['HMODataFOI']
cursor = list(collection.find({}, {'_id': False}))
df1 =  pd.DataFrame(list(cursor))
df=df1[['Licensed','Unlicensed2016']].astype(float)
ind = np.arange(26)
width = 0.35
ax = df.plot(kind='bar', title ="HMO Data for FOI 2016",figsize=(20,10),legend=True, fontsize=15)
ax.set_xlabel("Council",fontsize=12)
ax.set_xticklabels(df1['Council'])
ax.set_xticks(ind + width/2)
ax.set_ylabel("Licensed/Unlicensed Houses",fontsize=12)
plt.show()
# Out:
#                                   HMO Data for FOI 2016
#
#
#        FOI Data

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/project/Notebooks/LUN2016.png')

# %%
import pandas as pd
print()
print()
print()
print()
print('\x1b[1;31m'+'                                  HMO Data for FOI'+'\x1b[0m')
print()
print()
a = "       FOI Data"
print(a)


client = MongoClient()
db = client.test
collection = db['HMODataFOI']
cursor = list(collection.find({}, {'_id': False}))
result = json_normalize(cursor)

client = MongoClient()
db = client.test
collection = db['HMODataFOI']
cursor = list(collection.find({}, {'_id': False}))
df1 =  pd.DataFrame(list(cursor))
df=df1[['Licensed','Unlicensed2015','Unlicensed2016']].astype(float)
ind = np.arange(26)
width = 0.35
ax = df.plot(kind='bar', title ="HMO Data for FOI",figsize=(20,10),legend=True, fontsize=15)
ax.set_xlabel("Council",fontsize=12)
ax.set_xticklabels(df1['Council'])
ax.set_xticks(ind + width/2)
ax.set_ylabel("Licensed/Unlicensed Houses",fontsize=12)
plt.show()
# Out:
#                                   HMO Data for FOI
#
#
#        FOI Data

# %%
print()
print()
printmd('**HMO Regulations:-**')
a ="Your home is a house in multiple occupation (HMO) if both of the following apply:\n"

a = a + "- At least 3 tenants live there, forming more than 1 household\n"
a = a + "- You share toilet, bathroom or kitchen facilities with other tenants\n"
a = a + "- To be granted a licence under the scheme, properties must meet certain standards, such as presence of smoke detectors, fire doors and other safety equipment.\n"

a = a + "Your home is a large HMO if all of the following apply:\n"

a = a + "- It’s at least 3 storeys high\n"
a = a + "- At least 5 tenants live there, forming more than 1 household\n"
a = a + "- You share toilet, bathroom or kitchen facilities with other tenants\n\n"

a = a + "A household is either a single person or members of the same family who live together. A family includes people who are:\n"

a = a + "- Married or living together - including people in same-sex relationships\n"
a = a + "- Relatives or half-relatives, for example grandparents, aunts, uncles, siblings\n"
a = a + "- Step-parents and step-children\n"

print (a)
# Out:
# **HMO Regulations:-**
# Your home is a house in multiple occupation (HMO) if both of the following apply:
# - At least 3 tenants live there, forming more than 1 household
# - You share toilet, bathroom or kitchen facilities with other tenants
# - To be granted a licence under the scheme, properties must meet certain standards, such as presence of smoke detectors, fire doors and other safety equipment.
# Your home is a large HMO if all of the following apply:
# - It’s at least 3 storeys high
# - At least 5 tenants live there, forming more than 1 household
# - You share toilet, bathroom or kitchen facilities with other tenants
#
# A household is either a single person or members of the same family who live together. A family includes people who are:
# - Married or living together - including people in same-sex relationships
# - Relatives or half-relatives, for example grandparents, aunts, uncles, siblings
# - Step-parents and step-children

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
